# %% [markdown]
# # Depedencies loading

# %%
import pandas as pd

# %% [markdown]
# # Source data loading

# %%
df_erp_raw = pd.read_excel("./source_data/erp.xlsx", engine="openpyxl")
df_liaison_raw = pd.read_excel("./source_data/liaison.xlsx", engine="openpyxl")
df_web_raw = pd.read_excel("./source_data/web.xlsx", engine="openpyxl")
# Out:
# c:\Users\titig\Documents\formation_data_ia\07_optimisez_la_gestion_des_donnees\projet\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# c:\Users\titig\Documents\formation_data_ia\07_optimisez_la_gestion_des_donnees\projet\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# c:\Users\titig\Documents\formation_data_ia\07_optimisez_la_gestion_des_donnees\projet\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# # Raw data display

# %%
print("---- ERP ----")
print(df_erp_raw.head(20))
print("---- LIAISON ----")
print(df_liaison_raw.head(20))
print("---- WEB ----")
print(df_web_raw.head(20))
# Out:
# ---- ERP ----
#     product_id  onsale_web  price  stock_quantity stock_status  purchase_price
# 0         3847           1   24.2              16      instock           12.88
# 1         3849           1   34.3              10      instock           17.54
# 2         3850           1   20.8               0   outofstock           10.64
# 3         4032           1   14.1              26      instock            6.92
# 4         4039           1   46.0               3   outofstock           23.77
# 5         4040           1   34.3              12      instock           18.25
# 6         4041           1   32.7              12      instock           17.57
# 7         4042           1   31.2              15      instock           15.48
# 8         4043           1   60.0               0   outofstock           29.45
# 9         4045           1   42.6               5      instock           22.01
# 10        4046           1   80.0               2      instock           40.92
# ...
